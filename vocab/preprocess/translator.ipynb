# %% [markdown]
# # Import library

# %%
import re
import time
import json
from bs4 import BeautifulSoup
from openai import OpenAI
import pprint

# %%
client = OpenAI()

# %% [markdown]
# # Read the xml file

# %% [markdown]
# ### Find example sentences which are needed to translate from Webster dictionary

# %% [markdown]
# `<id>`: the word \
# `<stems>`: inflectional paradigm \
# `<sense>`: includes definitions and examples \
# `<dt>`: definition and may include 2 or more examples for different types \
# `<vi>`: example

# %%
def getData(alphabet):
    file = str()
    with open(f"../data/MW_Learners/LD_{alphabet}.xml", "r") as f:
      file = f.read()
    return file

# %%
def getExampleSentence(soup, target_word, num_word):
  pattern = r"{ldquo}|{rdquo}|{it}|{phrase}|{/phrase}|\[\=.*\]|\n"
  input_dict = {}
  word_count = 0
  find = False
  # Find all words that contain example sentence/phrase
  for word in soup.find_all('entry'):
    # Get the number of words we want
    # print(f"word count:{word_count}")
    if find and word_count == num_word:
      break

    # First, find the target word
    word_id = word.find('id').text
    # print(f"current word:{word_id}")
    if (not find) and (word_id != target_word):
      continue
    else:
      find = True
    # altername = word.find_all('va') + word.find_all('if')
    # print(f"alter name: {altername}")
    # sense = word.find_all('sense')

    # Get example sentences
    examples = word.find_all('vi')
    # If the word contains an example
    if examples != []:
      input_dict[word_id] = []
      # Delete annotations
      for sentence in examples:
        example = re.sub(pattern, "", sentence.text)
        example = example.replace(r"{/it}", "")
        # print(example)
        input_dict[word_id].append(example)
      print(f"ID: {word_id}")
      print(f"examples: {input_dict[word_id]}")
    print("---\n")
    word_count += 1
  return input_dict

# %% [markdown]
# ### Get example sentences from Macmillan dictionary

# %%
macmillan_xml = str()
with open(f"../data/test.xml", "r") as f:
  macmillan_xml = f.read()
macmillan_soup = BeautifulSoup(macmillan_xml, 'xml')

# %%
log_list =  macmillan_soup.find_all("HOMOGRAPH")
print(len(log_list))
pprint.pprint(log_list[15:20])
# Out:
# 1042
# [<HOMOGRAPH ID="363831"><HEAD><BASE-FORM><ENTRY0>ugh</ENTRY0><PRONS><PRON ID="0">x</PRON></PRONS><PRONS><PRON ID="1">g</PRON></PRONS></BASE-FORM><PART-OF-SPEECH>interjection</PART-OF-SPEECH></HEAD><SENSE><DEFINITION>used for writing the sound people make when they think something is extremely unpleasant</DEFINITION><trans lang="zh_HK">噁（表示極度厭惡）</trans><EXAMPLES><EXAMPLE>Ugh! That tastes disgusting!</EXAMPLE><trans lang="zh_HK">噁！真難吃！</trans></EXAMPLES></SENSE></HOMOGRAPH>,
#  <HOMOGRAPH ID="363841"><HEAD><BASE-FORM><ENTRY13>ugly</ENTRY13><PRONS><PRON ID="0">gli</PRON></PRONS></BASE-FORM><PART-OF-SPEECH>adj</PART-OF-SPEECH><STARS/></HEAD><SENSE45><SENSE-NUM>1</SENSE-NUM><DEFINITION>someone who is ugly has a face that is unpleasant to look at<USAGUC>Ugly is an unkind word, so people often use the word <VOCAB>plain</VOCAB> instead, to avoid causing offence</USAGUC></DEFINITION><trans lang="zh_HK">（人）難看的，醜陋的（不禮貌用語，常用plain來替代）</trans><EXAMPLES><EXAMPLE>The other man was hideously ugly.</EXAMPLE><trans lang="zh_HK">另一個男人奇醜無比。</trans></EXAMPLES><EXAMPLES><EXAMPLE>She wont wear T-shirts because she thinks her arms are ugly.</EXAMPLE><trans lang="zh_HK">她不願穿T恤，因為覺得手臂很難看。</trans></EXAMPLES><EXAMPLES><PATTERNS-COLLOCATIONS>as ugly as sin <GL>extremely ugly</GL></PATTERNS-COLLOCATIONS><trans lang="zh_HK">極其醜陋的</trans><EXAMPLE>She was rich and powerful and ugly as sin.</EXAMPLE><trans lang="zh_HK">她有錢有勢，但長得太醜。</trans></EXAMPLES><SUB-SENSE><SUB-SENSE-NUM>1a</SUB-SENSE-NUM><DEFINITION>something that is ugly is unpleasant to look at</DEFINITION><trans lang="zh_HK">（事物）難看的</trans><EXAMPLES><EXAMPLE>an ugly concrete bridge</EXAMPLE><trans lang="zh_HK">難看的混凝土橋</trans></EXAMPLES><EXAMPLES><EXAMPLE>Do you think its frame makes the picture look ugly?</EXAMPLE><trans lang="zh_HK">你覺得這畫框是不是讓畫變醜了？</trans></EXAMPLES></SUB-SENSE></SENSE45><SENSE45><SENSE-NUM>2</SENSE-NUM><DEFINITION>very unpleasant</DEFINITION><trans lang="zh_HK">令人厭惡的；卑劣的</trans><EXAMPLES><EXAMPLE>an ugly rumour</EXAMPLE><trans lang="zh_HK">卑劣的謠言</trans></EXAMPLES><EXAMPLES><EXAMPLE>ugly racist propaganda</EXAMPLE><trans lang="zh_HK">卑劣的種族主義宣傳</trans></EXAMPLES><EXAMPLES><PATTERNS-COLLOCATIONS>the ugly face of sth <GL>the unpleasant aspect of it</GL></PATTERNS-COLLOCATIONS><trans lang="zh_HK">事物令人厭惡的方面</trans><EXAMPLE>Critics have described the policy as the ugly face of Republicanism.</EXAMPLE><trans lang="zh_HK">評論家形容這項政策是共和制醜陋的一面。</trans></EXAMPLES></SENSE45><SENSE45><SENSE-NUM>3</SENSE-NUM><DEFINITION>an ugly situation involves violent or angry behaviour</DEFINITION><trans lang="zh_HK">暴力的；憤怒的</trans><EXAMPLES><EXAMPLE>There were ugly scenes following the match.</EXAMPLE><trans lang="zh_HK">比賽後發生了暴力事件。</trans></EXAMPLES><EXAMPLES><EXAMPLE>an ugly confrontation</EXAMPLE><trans lang="zh_HK">暴力衝突</trans></EXAMPLES><EXAMPLES><PATTERNS-COLLOCATIONS>turn ugly <GL>become unpleasant</GL></PATTERNS-COLLOCATIONS><trans lang="zh_HK">變得令人不愉快</trans><EXAMPLE>The situation turned ugly when one of the police officers was hit by a rock.</EXAMPLE><trans lang="zh_HK">一名警官遭石頭擊中後，情況開始惡化。</trans></EXAMPLES></SENSE45><PHRASE><MULTIWORD>sth <SLASH>rears</SLASH><SLASH>raises</SLASH> its ugly head</MULTIWORD><STYLE-LEVEL>informal</STYLE-LEVEL><DEFINITION>used for saying that something unpleasant starts to appear or happen</DEFINITION><trans lang="zh_HK">不好的事開始出現（或發生）</trans><EXAMPLES><EXAMPLE>The problem reared its ugly head again a few weeks later.</EXAMPLE><trans lang="zh_HK">這個惱人的問題幾週後又再出現了。</trans></EXAMPLES></PHRASE><RUNON><ENTRY>ugliness</ENTRY><RUNON-PART-OF-SPEECH>noun</RUNON-PART-OF-SPEECH><SYNTAX-CODING><REDUCED>U</REDUCED></SYNTAX-CODING></RUNON></HOMOGRAPH>,
#  <HOMOGRAPH ID="363851"><HEAD><BASE-FORM><ENTRY0>ugly duckling</ENTRY0></BASE-FORM><PART-OF-SPEECH>noun</PART-OF-SPEECH><SYNTAX-CODING><REDUCED>C</REDUCED></SYNTAX-CODING></HEAD><SENSE><DEFINITION>someone who people think will never be attractive or successful but who becomes very attractive or successful as they get older</DEFINITION><trans lang="zh_HK">醜小鴨</trans></SENSE><ETYMOLOGY>From a childrens story by Hans Christian Andersen, in which a young swan is unhappy because it thinks it is a duck but doesnt look like the other ducks. However, it later grows up and realizes it is a beautiful swan.</ETYMOLOGY><trans lang="zh_HK">源自安徒生童話，敘述一隻小天鵝自以為是鴨子，又長得不像其他鴨子而悶悶不樂，長大後才發現自己原來是隻漂亮的天鵝。</trans></HOMOGRAPH>,
#  <HOMOGRAPH ID="363891"><HEAD><BASE-FORM><ENTRY0>UHF</ENTRY0><PRONS><PRON ID="0">ju et ef</PRON></PRONS></BASE-FORM><PART-OF-SPEECH>abbrev</PART-OF-SPEECH></HEAD><SENSE><DEFINITION>Ultra High Frequency: a range of radio waves used for broadcasting television programmes</DEFINITION><trans lang="zh_HK">特高頻</trans></SENSE></HOMOGRAPH>,
#  <HOMOGRAPH ID="363861"><HEAD><BASE-FORM><ENTRY0>uh huh</ENTRY0><PRONS><PRON ID="0">h</PRON></PRONS></BASE-FORM><PART-OF-SPEECH>interjection</PART-OF-SPEECH></HEAD><SENSE><DEFINITION>used for writing the sound people make when they agree with something, or when they say yes to a question</DEFINITION><trans lang="zh_HK">嗯(表示肯定或同意)</trans><EXAMPLES><EXAMPLE>Ill see you at six oclock, then? Uh huh.</EXAMPLE><trans lang="zh_HK">「那麼，我6點鐘見你好嗎？」「嗯，好。」</trans></EXAMPLES></SENSE></HOMOGRAPH>]

# %%
pattern = r"{ldquo}|{rdquo}|{it}|{phrase}|{/phrase}|\[\=.*\]|\n"
macmillan_dict = {}
find = False
# Find all words that contain example sentence/phrase
for log in macmillan_soup.find_all('HOMOGRAPH'):
  # print(f"log: {log}")

  # First, find the target word
  word_id = log.find(re.compile(r"ENTRY.+$")).text
  if word_id != "ugly":
    continue

  # Get example sentences
  examples = log.find_all('EXAMPLES')
  # If the word contains an example
  if examples != []:
    macmillan_dict[word_id] = []
    # Delete annotations
    for sentence in examples:
      example = sentence.find("EXAMPLE").text
      trans_example = sentence.find("trans").text
      macmillan_dict[word_id].append([example, trans_example])
    print(f"ID: {word_id}")
    pprint.pprint(f"examples: {macmillan_dict[word_id]}", width = 120)
  print("---\n")
# Out:
# ID: ugly
# ("examples: [['The other man was hideously ugly.', '另一個男人奇醜無比。'], ['She wont wear T-shirts because she thinks her arms "
#  "are ugly.', '她不願穿T恤，因為覺得手臂很難看。'], ['She was rich and powerful and ugly as sin.', '極其醜陋的'], ['an ugly concrete "
#  "bridge', '難看的混凝土橋'], ['Do you think its frame makes the picture look ugly?', '你覺得這畫框是不是讓畫變醜了？'], ['an ugly rumour', "
#  "'卑劣的謠言'], ['ugly racist propaganda', '卑劣的種族主義宣傳'], ['Critics have described the policy as the ugly face of "
#  "Republicanism.', '事物令人厭惡的方面'], ['There were ugly scenes following the match.', '比賽後發生了暴力事件。'], ['an ugly "
#  "confrontation', '暴力衝突'], ['The situation turned ugly when one of the police officers was hit by a rock.', "
#  "'變得令人不愉快'], ['The problem reared its ugly head again a few weeks later.', '這個惱人的問題幾週後又再出現了。']]")
# ---

# %% [markdown]
# ### Prompts

# %%
# Zero-prompt
def queryZero(word, examples):
  prompt = fr"""Let us do it step by step to reach the best results.
Act as if you are an English teacher and translate the following sentences/phrases into traditional Mandarin Chinese (NOT simplified Chinese) for non-native English learners to learn how to understand and translate the word "{word}" in a sentence.
Please consult Cambridge English–Chinese (Traditional) Dictionary to find out about the range of translations of "{word}".

Present the translations in a list format, providing both the original sentence/phrase, and the translation(exclude pinyin).
Now, translate the following examples.
```
{examples}
```"""
  return prompt


# With Cambridge dictionary
def queryCambridge(word, examples):
  prompt = fr"""Let us do it step by step to reach the best results.
Act as if you are an English teacher and translate the following sentences/phrases into traditional Mandarin Chinese (NOT simplified Chinese) for non-native English learners to learn how to understand and translate the word "{word}" in a sentence.
Please consult Cambridge English–Chinese (Traditional) Dictionary to find out about the range of translations of "{word}".

Present the translations in a list format, providing both the original sentence/phrase, and the translation(exclude pinyin).
For example, if the word is "ugly", the output should resemble:

1. I think a lot of modern architecture is very ugly.
我覺得很多現代建築都非常難看。
2. Yesterday I saw the ugliest baby I've ever seen in my life.
昨天我看見了有生以來見過的最醜的嬰兒。

Now, translate the following examples.
```
{examples}
```"""
  return prompt

# With Macmillan dictionary
def queryMacmillan(word, examples):
  prompt = fr"""Let us do it step by step to reach the best results.
Act as if you are an English teacher and translate the following sentences/phrases into traditional Mandarin Chinese (NOT simplified Chinese) for non-native English learners to learn how to understand and translate the word "{word}" in a sentence.

Present the translations in a list format, providing both the original sentence/phrase, and the translation(exclude pinyin).
For example, if the word is "ugly", the output should resemble:

1. {macmillan_dict["ugly"][0][0]}
{macmillan_dict["ugly"][0][1]}
2. {macmillan_dict["ugly"][1][0]}
{macmillan_dict["ugly"][1][1]}

Now, translate the following examples.
```
{examples}
```"""
  return prompt

# With Cambridge and Macmillan dictionary
def queryMix(word, examples):
  prompt = fr"""Let us do it step by step to reach the best results.
Act as if you are an English teacher and translate the following sentences/phrases into traditional Mandarin Chinese (NOT simplified Chinese) for non-native English learners to learn how to understand and translate the word "{word}" in a sentence.
Please consult Cambridge English–Chinese (Traditional) Dictionary to find out about the range of translations of "{word}".

Present the translations in a list format, providing both the original sentence/phrase, and the translation(exclude pinyin).
For example, if the word is "ugly", the output should resemble:

1. {macmillan_dict["ugly"][0][0]}
{macmillan_dict["ugly"][0][1]}
2. {macmillan_dict["ugly"][1][0]}
{macmillan_dict["ugly"][1][1]}

Now, translate the following examples.
```
{examples}
```"""
  return prompt

# %%
def chat(word, examples, prompt_type, version):
  prompt = ""
  if prompt_type == "Zero":
    prompt = queryZero(word, examples)
  elif prompt_type == "Cambridge":
    prompt = queryCambridge(word, examples)
  elif prompt_type == "Macmillan":
    prompt = queryMacmillan(word, examples)
  else:
    prompt = queryMix(word, examples)

  # Get completion
  completion = client.chat.completions.create(
    model= version,
    messages=[
      {"role": "user", "content": f"{prompt}"},
    ]
  )
  respond = completion.choices[0].message.content
  return respond

def oneWordTranslate(word, examples, prompt_type, version="gpt-3.5-turbo"):
  begin_time = time.monotonic()
  respond = chat(word, examples, prompt_type, version)
  end_time = time.monotonic()
  duration = end_time - begin_time
  return (respond, duration)

def writeToFile(word, respond, duration):
  with open(f"{word}_result.txt", 'a') as f:
    f.write(f"{word}\n{respond}\n[duration: {duration}]\n---\n\n")

def writeToFileNoduration(word, respond):
  with open("transtion_result.txt", 'a') as f:
    f.write(f"{word}\n{respond}\n\n=====\n")

# %% [markdown]
# # Parsing

# %%
f = getData("a")
soup = BeautifulSoup(f, 'xml')

# %%
input_dict = getExampleSentence(soup, "ability", 1)
absence_dict = getExampleSentence(soup, "absence", 1)
# Out:
# ID: ability
# examples: ['a young woman with many remarkable musical/artistic/athletic abilities', 'a teacher with an ability to inspire his students', 'Does he have the ability  to fire employees?', "a writer's ability  to interest readers", 'a young woman of great musical/artistic/athletic ability', 'She has shown some ability with foreign languages.', 'He always works to the best of his ability. ']
# ---
#
# ID: absence
# examples: ['There was an absence ', 'The products showed a remarkable absence of defects.', 'In the absence of reform , progress was slow.', 'With the (continued) absence of rain , crops have begun to dry up.', 'He had many absences from work.', 'I expected to see her and was surprised by her absence.', 'He was conspicuous by his absence. ', 'She returned to the company after a long/prolonged absence.', "She'll be away for a month, but you know what they say—absence makes the heart grow fonder.", 'The study was completed in her absence.', "He was asked to speak in his brother's absence."]
# ---

# %%
input_dict.update(absence_dict)
pprint.pprint(input_dict, width = 120)
# Out:
# {'ability': ['a young woman with many remarkable musical/artistic/athletic abilities',
#              'a teacher with an ability to inspire his students',
#              'Does he have the ability  to fire employees?',
#              "a writer's ability  to interest readers",
#              'a young woman of great musical/artistic/athletic ability',
#              'She has shown some ability with foreign languages.',
#              'He always works to the best of his ability. '],
#  'absence': ['There was an absence ',
#              'The products showed a remarkable absence of defects.',
#              'In the absence of reform , progress was slow.',
#              'With the (continued) absence of rain , crops have begun to dry up.',
#              'He had many absences from work.',
#              'I expected to see her and was surprised by her absence.',
#              'He was conspicuous by his absence. ',
#              'She returned to the company after a long/prolonged absence.',
#              "She'll be away for a month, but you know what they say—absence makes the heart grow fonder.",
#              'The study was completed in her absence.',
#              "He was asked to speak in his brother's absence."]}

# %%
prompt_type_list = ["Zero", "Cambridge", "Macmillan", "Mix"]

# %%
for key, value in input_dict.items():
  prompt = queryMacmillan(key, value)
  print(prompt)
  print("---")
# Out:
# Let us do it step by step to reach the best results.
# Act as if you are an English teacher and translate the following sentences/phrases into traditional Mandarin Chinese (NOT simplified Chinese) for non-native English learners to learn how to understand and translate the word "ability" in a sentence.
#
# Present the translations in a list format, providing both the original sentence/phrase, and the translation(exclude pinyin).
# For example, if the word is "ugly", the output should resemble:
#
# 1. The other man was hideously ugly.
# 另一個男人奇醜無比。
# 2. She wont wear T-shirts because she thinks her arms are ugly.
# 她不願穿T恤，因為覺得手臂很難看。
#
# Now, translate the following examples.
# ```
# ['a young woman with many remarkable musical/artistic/athletic abilities', 'a teacher with an ability to inspire his students', 'Does he have the ability  to fire employees?', "a writer's ability  to interest readers", 'a young woman of great musical/artistic/athletic ability', 'She has shown some ability with foreign languages.', 'He always works to the best of his ability. ']
# ```
# ---
# Let us do it step by step to reach the best results.
# Act as if you are an English teacher and translate the following sentences/phrases into traditional Mandarin Chinese (NOT simplified Chinese) for non-native English learners to learn how to understand and translate the word "absence" in a sentence.
#
# Present the translations in a list format, providing both the original sentence/phrase, and the translation(exclude pinyin).
# For example, if the word is "ugly", the output should resemble:
#
# 1. The other man was hideously ugly.
# 另一個男人奇醜無比。
# 2. She wont wear T-shirts because she thinks her arms are ugly.
# 她不願穿T恤，因為覺得手臂很難看。
#
# Now, translate the following examples.
# ```
# ['There was an absence ', 'The products showed a remarkable absence of defects.', 'In the absence of reform , progress was slow.', 'With the (continued) absence of rain , crops have begun to dry up.', 'He had many absences from work.', 'I expected to see her and was surprised by her absence.', 'He was conspicuous by his absence. ', 'She returned to the company after a long/prolonged absence.', "She'll be away for a month, but you know what they say—absence makes the heart grow fonder.", 'The study was completed in her absence.', "He was asked to speak in his brother's absence."]
# ```
# ---

# %%
# respond, duration = oneWordTranslate('u', input_dict['u'])

# %%
# respond

# %%
# duration

# %%
count = 0
tranlated_dict = {}

# %%
for key, value in input_dict.items():
  single_word_trans = {}
  for type in prompt_type_list:
    respond, duration = oneWordTranslate(key, value, type, "gpt-4-1106-preview")
    single_word_trans[type] = [respond, duration]
    # writeToFile(key, respond, duration)
    # count += 1
    # if count == 10:
    #   break
  tranlated_dict[key] = single_word_trans

# %%
copy = tranlated_dict.copy()

# %%
pprint.pprint(copy)
# Out:
# {'ability': {'Cambridge': ['1. a young woman with many remarkable '
#                            'musical/artistic/athletic abilities\n'
#                            '一位具有許多了不起的音樂／藝術／運動才能的年輕女性。\n'
#                            '\n'
#                            '2. a teacher with an ability to inspire his '
#                            'students\n'
#                            '一位有激勵學生能力的老師。\n'
#                            '\n'
#                            '3. Does he have the ability to fire employees?\n'
#                            '他有解僱員工的能力嗎？\n'
#                            '\n'
#                            "4. a writer's ability to interest readers\n"
#                            '作家吸引讀者興趣的能力。\n'
#                            '\n'
#                            '5. a young woman of great '
#                            'musical/artistic/athletic ability\n'
#                            '一位具有極高音樂／藝術／運動才華的年輕女性。\n'
#                            '\n'
#                            '6. She has shown some ability with foreign '
#                            'languages.\n'
#                            '她展現出一些外語能力。\n'
#                            '\n'
#                            '7. He always works to the best of his ability.\n'
#                            '他總是發揮他最大的能力工作。',
#                            12.226522499928251],
#              'Macmillan': ['1. A young woman with many remarkable '
#                            'musical/artistic/athletic abilities.\n'
#                            '一位擁有許多了不起的音樂／藝術／運動才能的年輕女性。\n'
#                            '\n'
#                            '2. A teacher with an ability to inspire his '
#                            'students.\n'
#                            '一位有啟發學生能力的老師。\n'
#                            '\n'
#                            '3. Does he have the ability to fire employees?\n'
#                            '他有解僱員工的能力嗎？\n'
#                            '\n'
#                            "4. A writer's ability to interest readers.\n"
#                            '作家吸引讀者的能力。\n'
#                            '\n'
#                            '5. A young woman of great '
#                            'musical/artistic/athletic ability.\n'
#                            '一位具備極高音樂／藝術／運動才能的年輕女性。\n'
#                            '\n'
#                            '6. She has shown some ability with foreign '
#                            'languages.\n'
#                            '她展現了一些外語能力。\n'
#                            '\n'
#                            '7. He always works to the best of his ability.\n'
#                            '他總是盡其所能地工作。',
#                            7.846649750019424],
#              'Mix': ['Here are the requested translations:\n'
#                      '\n'
#                      '1. A young woman with many remarkable '
#                      'musical/artistic/athletic abilities.\n'
#                      '一位有許多非凡音樂／藝術／運動才能的年輕女性。\n'
#                      '\n'
#                      '2. A teacher with an ability to inspire his students.\n'
#                      '一位具有啟發學生能力的老師。\n'
#                      '\n'
#                      '3. Does he have the ability to fire employees?\n'
#                      '他有解僱員工的能力嗎？\n'
#                      '\n'
#                      "4. A writer's ability to interest readers.\n"
#                      '作家吸引讀者的能力。\n'
#                      '\n'
#                      '5. A young woman of great musical/artistic/athletic '
#                      'ability.\n'
#                      '一位具有極高音樂／藝術／運動才藝的年輕女性。\n'
#                      '\n'
#                      '6. She has shown some ability with foreign languages.\n'
#                      '她展現出一些外語能力。\n'
#                      '\n'
#                      '7. He always works to the best of his ability.\n'
#                      '他總是盡其所能地工作。',
#                      8.923128832946531],
#              'Zero': ['Consulting the Cambridge English–Chinese (Traditional) '
#                       'Dictionary, we can translate the word "ability" into '
#                       'traditional Mandarin Chinese as "能力" (nengli), "才能" '
#                       '(caineng) or "才幹" (caigan), depending on the context. '
#                       'Here are the translations for your provided examples:\n'
#                       '\n'
#                       '1. a young woman with many remarkable '
#                       'musical/artistic/athletic abilities\n'
#                       '   - 一位擁有許多顯著音樂／藝術／運動才能的年輕女性\n'
#                       '\n'
#                       '2. a teacher with an ability to inspire his students\n'
#                       '   - 一位能夠激勵學生的老師\n'
#                       '\n'
#                       '3. Does he have the ability to fire employees?\n'
#                       '   - 他有解僱員工的能力嗎？\n'
#                       '\n'
#                       "4. a writer's ability to interest readers\n"
#                       '   - 作家吸引讀者的能力\n'
#                       '\n'
#                       '5. a young woman of great musical/artistic/athletic '
#                       'ability\n'
#                       '   - 一位擁有極高音樂／藝術／運動才能的年輕女性\n'
#                       '\n'
#                       '6. She has shown some ability with foreign languages.\n'
#                       '   - 她展現了一些學習外語的能力。\n'
#                       '\n'
#                       '7. He always works to the best of his ability.\n'
#                       '   - 他總是發揮最大的能力工作。',
#                       12.819859249982983]},
#  'absence': {'Cambridge': ['Using the Cambridge English–Chinese (Traditional) '
#                            'Dictionary where possible to find suitable '
#                            'translations, here are the requested '
#                            'sentences/phrases translated into Traditional '
#                            'Mandarin Chinese:\n'
#                            '\n'
#                            '1. There was an absence\n'
#                            '有一個缺席。\n'
#                            '\n'
#                            '2. The products showed a remarkable absence of '
#                            'defects.\n'
#                            '該產品顯示出了顯著的無瑕疵。\n'
#                            '\n'
#                            '3. In the absence of reform, progress was slow.\n'
#                            '在改革缺乏的情況下，進展緩慢。\n'
#                            '\n'
#                            '4. With the (continued) absence of rain, crops '
#                            'have begun to dry up.\n'
#                            '由於持續沒有雨水，農作物已開始枯萎。\n'
#                            '\n'
#                            '5. He had many absences from work.\n'
#                            '他有許多次工作缺席。\n'
#                            '\n'
#                            '6. I expected to see her and was surprised by her '
#                            'absence.\n'
#                            '我本以為會見到她，沒想到她缺席，感到意外。\n'
#                            '\n'
#                            '7. He was conspicuous by his absence.\n'
#                            '他因缺席而引人注目。\n'
#                            '\n'
#                            '8. She returned to the company after a '
#                            'long/prolonged absence.\n'
#                            '她在長時間/長期缺席後回到了公司。\n'
#                            '\n'
#                            "9. She'll be away for a month, but you know what "
#                            'they say—absence makes the heart grow fonder.\n'
#                            '她將不在一個月，但你知道他們怎麼說—相隔越遠，心越思。\n'
#                            '\n'
#                            '10. The study was completed in her absence.\n'
#                            '這項研究在她不在的情況下完成了。\n'
#                            '\n'
#                            "11. He was asked to speak in his brother's "
#                            'absence.\n'
#                            '他在他哥哥不在時被要求發言。\n'
#                            '\n'
#                            'Please note that translations may vary due to '
#                            'context, specific usage, and nuances in both '
#                            'English and Chinese languages. The provided '
#                            'phrases are translated to reflect the general '
#                            "meaning of 'absence' as accurately as possible.",
#                            13.170417082961649],
#              'Macmillan': ['1. There was an absence.\n'
#                            '曾經有一段不在場。\n'
#                            '\n'
#                            '2. The products showed a remarkable absence of '
#                            'defects.\n'
#                            '這些產品顯示出驚人的無瑕疵。\n'
#                            '\n'
#                            '3. In the absence of reform, progress was slow.\n'
#                            '在改革缺席的情況下，進展緩慢。\n'
#                            '\n'
#                            '4. With the (continued) absence of rain, crops '
#                            'have begun to dry up.\n'
#                            '隨著（持續的）雨水缺乏，農作物已開始乾枯。\n'
#                            '\n'
#                            '5. He had many absences from work.\n'
#                            '他有許多次工作缺席。\n'
#                            '\n'
#                            '6. I expected to see her and was surprised by her '
#                            'absence.\n'
#                            '我原本期待見到她，對她的不在感到驚訝。\n'
#                            '\n'
#                            '7. He was conspicuous by his absence.\n'
#                            '他因缺席而顯得格外引人注目。\n'
#                            '\n'
#                            '8. She returned to the company after a '
#                            'long/prolonged absence.\n'
#                            '她在長時間缺席後返回了公司。\n'
#                            '\n'
#                            "9. She'll be away for a month, but you know what "
#                            'they say—absence makes the heart grow fonder.\n'
#                            '她將外出一個月，但你知道他們怎麼說—相隔越遠，心越貼近。\n'
#                            '\n'
#                            '10. The study was completed in her absence.\n'
#                            '研究在她不在時完成了。\n'
#                            '\n'
#                            "11. He was asked to speak in his brother's "
#                            'absence.\n'
#                            '他被要求在他兄弟不在的時候發言。',
#                            11.066460040980019],
#              'Mix': ['1. There was an absence\n'
#                      '有一種缺席感\n'
#                      '\n'
#                      '2. The products showed a remarkable absence of defects.\n'
#                      '該產品顯示出非常少見的無缺陷狀態。\n'
#                      '\n'
#                      '3. In the absence of reform, progress was slow.\n'
#                      '在沒有改革的情況下，進展緩慢。\n'
#                      '\n'
#                      '4. With the (continued) absence of rain, crops have '
#                      'begun to dry up.\n'
#                      '由於持續缺雨，農作物開始乾枯。\n'
#                      '\n'
#                      '5. He had many absences from work.\n'
#                      '他工作缺勤很多次。\n'
#                      '\n'
#                      '6. I expected to see her and was surprised by her '
#                      'absence.\n'
#                      '我本以為會見到她，她的不在讓我感到意外。\n'
#                      '\n'
#                      '7. He was conspicuous by his absence.\n'
#                      '他因缺席而引人注目。\n'
#                      '\n'
#                      '8. She returned to the company after a long/prolonged '
#                      'absence.\n'
#                      '她在長時間缺席後回到了公司。\n'
#                      '\n'
#                      "9. She'll be away for a month, but you know what they "
#                      'say—absence makes the heart grow fonder.\n'
#                      '她將外出一個月，但你知道他們怎麼說——久別勝新歡。\n'
#                      '\n'
#                      '10. The study was completed in her absence.\n'
#                      '研究在她不在時完成了。\n'
#                      '\n'
#                      "11. He was asked to speak in his brother's absence.\n"
#                      '他被要求在他兄弟缺席時發言。',
#                      15.050858957925811],
#              'Zero': ['Certainly! Below are the translated sentences into '
#                       'traditional Mandarin Chinese:\n'
#                       '\n'
#                       '1. There was an absence.\n'
#                       '   - 有一個缺席。\n'
#                       '\n'
#                       '2. The products showed a remarkable absence of '
#                       'defects.\n'
#                       '   - 該產品顯示出顯著的無缺陷。\n'
#                       '\n'
#                       '3. In the absence of reform, progress was slow.\n'
#                       '   - 在改革缺乏的情況下，進展緩慢。\n'
#                       '\n'
#                       '4. With the (continued) absence of rain, crops have '
#                       'begun to dry up.\n'
#                       '   - 因為持續缺雨，農作物開始乾枯。\n'
#                       '\n'
#                       '5. He had many absences from work.\n'
#                       '   - 他工作缺席很多次。\n'
#                       '\n'
#                       '6. I expected to see her and was surprised by her '
#                       'absence.\n'
#                       '   - 我本來期待見到她，對她的不在感到驚訝。\n'
#                       '\n'
#                       '7. He was conspicuous by his absence.\n'
#                       '   - 他因不在而顯得很突出。\n'
#                       '\n'
#                       '8. She returned to the company after a long/prolonged '
#                       'absence.\n'
#                       '   - 她在長時間缺席後回到了公司。\n'
#                       '\n'
#                       "9. She'll be away for a month, but you know what they "
#                       'say—absence makes the heart grow fonder.\n'
#                       '   - 她將離開一個月，但你知道他們怎麼說—相隔越遠心越近。\n'
#                       '\n'
#                       '10. The study was completed in her absence.\n'
#                       '    - 研究在她不在的情況下完成。\n'
#                       '\n'
#                       "11. He was asked to speak in his brother's absence.\n"
#                       '    - 他在他兄弟不在時被要求發言。\n'
#                       '\n'
#                       'Please note that translations can vary slightly based '
#                       'on context and the specific nuances of the original '
#                       'English sentences. The provided translations express '
#                       'one of the possible ways to interpret each sentence '
#                       'that contains the word "absence."',
#                       14.45910862495657]}}

# %%
# for key, value in tranlated_dict.items():
#   print(key, value[1])
#   word = key + "2"
#   writeToFile(key + "2", value[0], value[1])

# %%
with open("tranlated_test.json", "w") as f:
  json.dump(tranlated_dict, f)

# %%
with open("tranlated.json", "r") as f:
  t_dict = json.load(f)

# %%
t_dict
